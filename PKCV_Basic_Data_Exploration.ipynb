# %% [markdown]
# <a href="https://colab.research.google.com/github/Auvarmf/PKCV/blob/main/PKCV_Basic_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# save filepath to variable for easier access
melbourne_file_path = pd.read_csv("https://raw.githubusercontent.com/rahmantaufik27/dataset/main/study/student_score_pass.csv")
# read the data and store data in DataFrame titled melbourne_data
melbourne_file_path
# print a summary of the data in Melbourne data
melbourne_file_path.describe()
# Out:
#                 npm  activeness_score  assignment_score  pre_test_score  \
# count  3.720000e+02        372.000000         364.00000      336.000000
# mean   2.022041e+09         92.758065          85.32967       57.988095
# std    1.075314e+02         44.578778           8.62638       26.472625
# min    2.022041e+09        -96.000000          70.00000       10.000000
# 25%    2.022041e+09         85.000000          79.00000       35.000000
# 50%    2.022041e+09         90.000000          85.00000       61.500000
# 75%    2.022041e+09         95.000000          92.00000       81.000000
# max    2.022041e+09        666.000000         100.00000      100.000000
#
#        post_test_score  midterm_test_score  end_semester_test_score
# count       363.000000          361.000000               372.000000
# mean         52.798898           53.398892                53.330645
# std          25.691020           24.968789                30.695107
# ...
